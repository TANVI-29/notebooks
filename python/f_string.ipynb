# %% [markdown]
# #  f strings

# %%
planet_name=input("Name of planet:")
moons_planet=int(input(f"number of moons of {planet_name}:"))
print(f"The planet {planet_name} have {moons_planet} moons.")
# Out:
# Name of planet:Mars
# number of moons of Mars:2
# The planet Mars have 2 moons.

# %%
str1="Hi.My name is Tanvi "
str2="I am learning python"
print(f"{str1} {str2}")
# Out:
# Hi.My name is Tanvi  I am learning python
